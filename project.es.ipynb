# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
price_max=ds.loc[ds['price'].idxmax()]
print("La casa más cara se encuentra en", price_max['address'], "y su precio es", price_max['price'])
# Out:
# La casa más cara se encuentra en El Escorial y su precio es 8500000

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
price_min_over = ds[ds['price']>0]
price_min = price_min_over.loc[price_min_over['price'].idxmin()]
print("La casa más barata se encuentra en", price_min['address'], "y su precio es", price_min['price'])
# Out:
# La casa más barata se encuentra en Berlin, Coslada y su precio es 600

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO
surface_max=ds.loc[ds['surface'].idxmax()]
surface_min=ds.loc[ds['surface'].idxmin()]

print("La casa más grande se encuentra en", surface_max['address'], "y mide", surface_max['surface'])
print("La casa más pequeña se encuentra en", surface_min['address'], "y mide", surface_min['surface'])
# Out:
# La casa más grande se encuentra en Sevilla la Nueva y mide 249000.0
# La casa más pequeña se encuentra en Calle Amparo,  Madrid Capital y mide 15.0

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
poblaciones=ds['level5'].unique()
print(",".join(poblaciones))
print(len(poblaciones))
# Out:
# Arganda del Rey,Fuenlabrada,Boadilla del Monte,Las Rozas de Madrid, Madrid Capital,Villaviciosa de Odón,Pinto,Valdemoro,Navalcarnero,Pozuelo de Alarcón,Torrejón de Ardoz,Navalagamella,San Sebastián de los Reyes,Rivas-vaciamadrid,Alpedrete,Móstoles,San Fernando de Henares,Coslada,Becerril de la Sierra,Alcalá de Henares,Chinchón,Parla,Alcorcón,El Escorial,Leganés,Pedrezuela,Majadahonda,Villanueva de la Cañada,Villanueva del Pardillo,Torrelodones,Moralzarzal,Mejorada del Campo,Aranjuez,Corpa,Getafe,Velilla de San Antonio,Sevilla la Nueva,San Martín de la Vega,Villalbilla,Collado Villalba,Alcobendas,El Molar (Madrid),Moraleja de Enmedio,Algete,Campo Real,Torrejón de la Calzada,Colmenar Viejo,Valdemorillo,Fuente El Saz de Jarama,Tres Cantos,Arroyomolinos (Madrid),Griñón,Paracuellos de Jarama,Guadarrama,Titulcia,Galapagar,Collado Mediano,Los Molinos,San Lorenzo de El Escorial,Loeches,San Martín de Valdeiglesias,Navas del Rey,Bustarviejo,Manzanares El Real,Carabaña,Casarrubuelos,Cercedilla,
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO
ds_nulo=ds.isnull().any().any()
print(ds_nulo)
ds_columnas_nulo=ds.columns[ds.isnull().any()]
print(ds_columnas_nulo)
# Out:
# True
# Index(['realEstate_name', 'phone_realEstate', 'rooms', 'bathrooms', 'surface',
#        'description', 'level4', 'level6', 'level7', 'level8', 'zipCode',
#        'customZone', 'pps'],
#       dtype='object')

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO
tamaño_original=ds.shape
ds_modificado=ds.dropna()
tamaño_modificado=ds_modificado.shape
print("tamaño orginial",ds.shape)
print("después de modificar",ds_modificado.shape)
print("numero de filas eliminadas",tamaño_original[0]-tamaño_modificado[0])
# Out:
# tamaño orginial (15335, 38)
# después de modificar (0, 38)
# numero de filas eliminadas 15335

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO
ds_arroyomolinos=ds[ds['level5']=='Arroyomolinos (Madrid)']
media=round(ds_arroyomolinos['price'].mean(),2)
#print(ds_arroyomolinos['price'])
print("la media de precios es:",media)
# Out:
# la media de precios es: 294541.6

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code
ds_arroyomolinos=ds[ds['level5']=='Arroyomolinos (Madrid)']

# Trazar el histograma de precios
plt.hist(ds_arroyomolinos['price'],bins=30)
plt.title("Histograma de precios")
plt.grid()
plt.show()

# %% [markdown]
# Podemos observar que en Arroyomolinos hay mas casas por debajo de los 300000 euros,aunque necesitamos más datos para sacar algún tipo de info concluyente

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO
ds_valdemorillo=ds[ds['level5']=='Valdemorillo']
ds_galapagar=ds[ds['level5']=='Galapagar']
mean_valdemorillo=round(ds_valdemorillo['price'].mean(),2)
mean_galapagar=round(ds_galapagar['price'].mean(),2)
print("La media de precios de Valdemorillo es:",mean_valdemorillo)
print("La media de precios de Galapagar es:",mean_galapagar)
# Out:
# La media de precios de Valdemorillo es: 363860.29
# La media de precios de Galapagar es: 360063.2

# %% [markdown]
# La media de precios es casi igual aunque es superior en Valdemorillo, no es información suficiente para saber si es más caro o no

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO
ds['pps']=ds['price']/ds['surface']
ds_valdemorillo=ds[ds['level5']=='Valdemorillo']
ds_galapagar=ds[ds['level5']=='Galapagar']
mean_valdemorillo=round(ds_valdemorillo['pps'].mean(),2)
mean_galapagar=round(ds_galapagar['pps'].mean(),2)
print("La media de Valdemorillo es:",mean_valdemorillo)
print("La media de Galapagar es:",mean_galapagar)
# Out:
# La media de Valdemorillo es: 1317.95
# La media de Galapagar es: 1606.32

# %% [markdown]
# Los promedios no son iguales, podemos deducir a priori que el metro cuadrado en Galapagar es más caro

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código
price_min_over = ds[ds['price']>0]
plt.scatter(price_min_over['price'],price_min_over['surface'])
plt.xlim(1,4000000)
plt.ylim(1,500)
plt.title("Relación precio/superficie")
plt.grid()
plt.show()

# %% [markdown]
# Se observa que la tendencia es que cuanto más grande es la casa tambien es más cara, sin embargo depende de la zona y podemos decir que hay un problema actual con el precio de la vivienda que llega a unos valores altisimos

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO

inmobiliarias=ds['realEstate_name'].dropna().unique()
#print(",".join(inmobiliarias))
numero_agencias=len(inmobiliarias)
print(f"el numero de agencias es {numero_agencias}")
# Out:
# el numero de agencias es 1821

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO
poblacion_max=ds.value_counts(ds['level5'])
print(poblacion_max)
print(f"la población con más cantidad de casas es {poblacion_max.index[0]} y tiene {poblacion_max.iloc[0]} casas")
# Out:
# level5
#  Madrid Capital         6643
# Alcalá de Henares        525
# Las Rozas de Madrid      383
# Móstoles                 325
# Getafe                   290
#                         ...
# Montejo de la Sierra       1
# Lozoya                     1
# Pinilla del Valle          1
# Rascafría                  1
# Piñuécar-gandullas         1
# Name: count, Length: 168, dtype: int64
# la población con más cantidad de casas es  Madrid Capital y tiene 6643 casas

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO
ds_transicion=ds.isin(['Fuenlabrada','Leganés','Getafe','Alcorcón'])
ds_cinturon_sur=ds.loc[ds_transicion['level5']==True]
#ds_cinturon_sur
ds_cinturon_sur['level5'].unique()
# Out:
# array(['Fuenlabrada', 'Alcorcón', 'Leganés', 'Getafe'], dtype=object)

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code
ds_fuenlabrada=ds_cinturon_sur[ds_cinturon_sur['level5']=='Fuenlabrada']
mediana_fuenlabrada=ds_fuenlabrada['price'].median()
ds_leganes=ds_cinturon_sur[ds_cinturon_sur['level5']=='Leganés']
mediana_leganes=ds_leganes['price'].median()
ds_getafe=ds_cinturon_sur[ds_cinturon_sur['level5']=='Getafe']
mediana_getafe=ds_getafe['price'].median()
ds_alcorcon=ds_cinturon_sur[ds_cinturon_sur['level5']=='Alcorcón']
mediana_alcorcon=ds_alcorcon['price'].median()
plt.bar(ds_fuenlabrada['level5'],mediana_fuenlabrada)
plt.bar(ds_leganes['level5'],mediana_leganes)
plt.bar(ds_getafe['level5'],mediana_getafe)
plt.bar(ds_alcorcon['level5'],mediana_alcorcon)
plt.title("Gráfico de barras de mediana de precios")
plt.grid()
plt.show()

# %% [markdown]
# Se observa que la mayor mediana pertenece a Getafe, aunque no es información suficiente para determinar si es la zona más cara

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO
print("La media de precios es:",round(ds_cinturon_sur['price'].mean(),2))
print("Y su varianza:",round(ds_cinturon_sur['price'].var(ddof=0),2))
print("La media de habitaciones es:",round(ds_cinturon_sur['rooms'].mean(),2))
print("Y su varianza:",round(ds_cinturon_sur['rooms'].var(ddof=0),2))
print("La media de baños es:",round(ds_cinturon_sur['bathrooms'].mean(),2))
print("Y su varianza:",round(ds_cinturon_sur['bathrooms'].var(ddof=0),2))
print("La media de superficie es:",round(ds_cinturon_sur['surface'].mean(),2))
print("Y su varianza:",round(ds_cinturon_sur['surface'].var(ddof=0),2))
# Out:
# La media de precios es: 223094.48
# Y su varianza: 14904916165.7
# La media de habitaciones es: 3.02
# Y su varianza: 0.72
# La media de baños es: 1.63
# Y su varianza: 0.57
# La media de superficie es: 111.75
# Y su varianza: 4257.63

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO
price_max_fuenlabrada=ds_fuenlabrada.loc[(ds_fuenlabrada['price'].idxmax())]
print(f"La casa mas cara de Fuenlabrada cuesta: {price_max_fuenlabrada['price']} y la dirección es: {price_max_fuenlabrada['address']}")
price_max_getafe=ds_getafe.loc[(ds_getafe['price'].idxmax())]
print(f"La casa mas cara de Getafe cuesta: {price_max_getafe['price']} y la dirección es: {price_max_getafe['address']}")
price_max_alcorcon=ds_alcorcon.loc[(ds_alcorcon['price'].idxmax())]
print(f"La casa mas cara de Alcorcón cuesta:{price_max_alcorcon['price']} y la dirección es: {price_max_alcorcon['address']}")
price_max_leganes=ds_leganes.loc[(ds_leganes['price'].idxmax())]
print(f"La casa mas cara de Leganés cuesta:{price_max_leganes['price']} y la dirección es: {price_max_leganes['address']}")
# Out:
# La casa mas cara de Fuenlabrada cuesta: 490000 y la dirección es: Calle de Paulo Freire, 5, Fuenlabrada
# La casa mas cara de Getafe cuesta: 1050000 y la dirección es: Getafe
# La casa mas cara de Alcorcón cuesta:950000 y la dirección es: Alcorcón
# La casa mas cara de Leganés cuesta:650000 y la dirección es: Avenida Reina Sofía, Leganés

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO
ds_cinturon_sur_norm=ds_cinturon_sur.copy()
ds_cinturon_sur_norm['price_z'] = (ds_cinturon_sur_norm['price'] - ds_cinturon_sur_norm['price'].mean()) / ds_cinturon_sur_norm['price'].std()
#ds_cinturon_sur_norm['price_z']
ds_fuenlabrada_n=ds_cinturon_sur_norm[ds_cinturon_sur_norm['level5']=='Fuenlabrada']
ds_leganes_n=ds_cinturon_sur_norm[ds_cinturon_sur_norm['level5']=='Leganés']
ds_getafe_n=ds_cinturon_sur_norm[ds_cinturon_sur_norm['level5']=='Getafe']
ds_alcorcon_n=ds_cinturon_sur_norm[ds_cinturon_sur_norm['level5']=='Alcorcón']
plt.subplot(2,2,1)
plt.title("precion normalizado fuenlabrada")
plt.hist(ds_fuenlabrada_n['price_z'],alpha=0.5,label='precio fuenlabrada',edgecolor='black', density=True)
plt.subplot(2,2,2)
plt.title("precion normalizado leganés")
plt.hist(ds_leganes_n['price_z'],alpha=0.5,label='precio leganés',edgecolor='black', density=True)
plt.subplot(2,2,3)
plt.title("precio normalizado getafe")
plt.hist(ds_getafe_n['price_z'],alpha=0.5,label='precio getafe',edgecolor='black', density=True)
plt.subplot(2,2,4)
plt.hist(ds_alcorcon_n['price_z'],alpha=0.5,label='precio alcorcón',edgecolor='black', density=True)
plt.title("precio normalizado alcorcón")
plt.grid()
plt.tight_layout()
plt.show()

# %%
#HISTOGRAMAS SUPERPUESTOS
plt.hist(ds_fuenlabrada_n['price_z'],alpha=0.5,label='precio fuenlabrada',edgecolor='black', density=True)
plt.hist(ds_leganes_n['price_z'],alpha=0.5,label='precio leganés',edgecolor='black', density=True)
plt.hist(ds_getafe_n['price_z'],alpha=0.5,label='precio getafe',edgecolor='black', density=True)
plt.hist(ds_alcorcon_n['price_z'],alpha=0.5,label='precio alcorcón',edgecolor='black', density=True)

plt.axvline(x=0, color='red', linestyle='--', linewidth=2, label='Centro (0)')
plt.title("Histograma de precios normalizados")
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO
print(f"La media de precios en Getafe es {round(ds_getafe['pps'].mean(),2)} y su varianza es {round(ds_getafe['pps'].var(),2)}")
print(f"La media de precios en Alcorcón es {round(ds_alcorcon['pps'].mean(),2)} y su varianza es {round(ds_alcorcon['pps'].var(),2)}")
print("Podemos deducir que en general los precios en Getafe son más bajos pero hay una fluctuación mayor lo cual indica inestabilidad y mayor riesgo a la hora de comprar/vender")
# Out:
# La media de precios en Getafe es 2066.31 y su varianza es 550375.11
# La media de precios en Alcorcón es 2239.3 y su varianza es 291547.65
# Podemos deducir que en general los precios en Getafe son más bajos pero hay una fluctuación mayor lo cual indica inestabilidad y mayor riesgo a la hora de comprar/vender

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.scatter(ds_fuenlabrada['price'],ds_fuenlabrada['surface'])
plt.title("Precio/Superfice Fuenlabrada")
plt.grid()
plt.subplot(2,2,2)
plt.scatter(ds_leganes['price'],ds_leganes['surface'])
plt.title("Precio/Superfice Leganés")
plt.grid()
plt.subplot(2,2,3)
plt.scatter(ds_getafe['price'],ds_getafe['surface'])
plt.title("Precio/Superfice Getafe")
plt.grid()
plt.subplot(2,2,4)
plt.scatter(ds_alcorcon['price'],ds_alcorcon['surface'])
plt.title("Precio/Superfice Alcorcón")
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map,basemaps,Marker

# Mapa centrado en Madrid
mapa = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)

mapa
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
#HAY QUE EJECUTAR ESTA CELDA PARA HACER LA CONVERSIÓN DE DATOS A FLOAT CON PUNTO
ds_cinturon_sur['latitude'] = ds_cinturon_sur['latitude'].str.replace(',', '.')
ds_cinturon_sur['longitude'] = ds_cinturon_sur['longitude'].str.replace(',', '.')

ds_cinturon_sur['latitude'] = ds_cinturon_sur['latitude'].astype(float)
ds_cinturon_sur['longitude'] = ds_cinturon_sur['longitude'].astype(float)

# %%
## Aquí: traza la coordenadas de los estados
#print(ds_fuenlabrada[['latitude','longitude']])
#print(ds_getafe[['latitude','longitude']])
#print(ds_leganes[['latitude','longitude']])
#print(ds_alcorcon[['latitude','longitude']])


## PON TU CÓDIGO AQUÍ:
dictionary=ds_cinturon_sur[['latitude','longitude']].to_dict(orient='records')

coordenadas = list(zip(ds_cinturon_sur['latitude'], ds_cinturon_sur['longitude']))
#print(coordenadas)

mapa = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)

for coord in coordenadas:
    mapa.add_layer(Marker(location=coord))
mapa
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…
